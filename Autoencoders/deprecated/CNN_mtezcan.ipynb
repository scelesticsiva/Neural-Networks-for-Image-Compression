# %%
import tensorflow as tf
import skimage.io
import skimage.color
import numpy as np
from pprint import pprint

# %%
import read_cifar10 as cf10

#@read_data.restartable
def cifar10_dataset_generator(dataset_name, batch_size, restrict_size=1000):
    assert dataset_name in ['train', 'test']
    assert batch_size > 0 or batch_size == -1  # -1 for entire dataset
    
    X_all_unrestricted, y_all = (cf10.load_training_data() if dataset_name == 'train'
                                 else cf10.load_test_data())
    
    actual_restrict_size = restrict_size if dataset_name == 'train' else int(1e10)
    X_all = X_all_unrestricted[:actual_restrict_size]
    data_len = X_all.shape[0]
    batch_size = batch_size if batch_size > 0 else data_len
    
    X_all_padded = np.concatenate([X_all, X_all[:batch_size]], axis=0)
    y_all_padded = np.concatenate([y_all, y_all[:batch_size]], axis=0)
    
    for slice_i in range(math.ceil(data_len / batch_size)):
        idx = slice_i * batch_size
        #X_batch = X_all_padded[idx:idx + batch_size]
        X_batch = X_all_padded[idx:idx + batch_size]*255  # bugfix: thanks Zezhou Sun!
        y_batch = np.ravel(y_all_padded[idx:idx + batch_size])
        yield X_batch.astype(np.uint8), y_batch.astype(np.uint8)

cifar10_dataset_generators = {
    'train': cifar10_dataset_generator('train', 1000),
    'test': cifar10_dataset_generator('test', -1)
}

# %%
#Load cifar-10 data
cf10_tr=cf10.load_training_data()
cf10_tr_img=cf10_tr[0]
cf10_tr_label = cf10_tr[1]

cf10_test=cf10.load_test_data()
cf10_test_img=cf10_test[0]
cf10_test_label = cf10_test[1]

# %%
#Calculate the metrics for jpg
mse_jpg=np.zeros((10000,1))
psnr_jpg=np.zeros((10000,1))
#Save cifar test images
for k in range(10000):
    img_gray=(255*cf10_test_img_gray[k,:,:]).astype(np.uint8)
    skimage.io.imsave('../cifar10_jpg/'+str(k)+'.jpg',img_gray)
    
    img_vec = img_gray.reshape([1,-1])
    cf10_test_vec[k,:]=img_vec
    img_recons = skimage.io.imread('../cifar10_jpg/'+str(k)+'.jpg')
    mse=(((img_recons.astype(float)-img_gray.astype(float))/255.)**2).mean()
    mse_jpg[k]=mse
    psnr_jpg[k]=10.*np.log10(1./mse)

print('test is done')
for k in range(50000):
    img_gray=(255*cf10_tr_img_gray[k,:,:]).astype(np.uint8)
    img_vec = img_gray.reshape([1,-1])
    cf10_tr_vec[k,:]=img_vec
    
print('train is done')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-82f4681b4665> in <module>()
#       4 #Save cifar test images
#       5 for k in range(10000):
# ----> 6     img_gray=(255*cf10_test_img_gray[k,:,:]).astype(np.uint8)
#       7     skimage.io.imsave('../cifar10_jpg/'+str(k)+'.jpg',img_gray)
#       8
#
# NameError: name 'cf10_test_img_gray' is not defined

# %%
#Not necessary
print(mse_jpg.mean())
print(psnr_jpg.mean())
# Out:
# 0.0
# 0.0

# %%
import skimage.io
import numpy as np
def img2block(im):
    #lion[:2816,:4224,:]
    #skimage.io.imshow(lion)
    #skimage.io.show()
    
    im = im.astype(np.float32)
    row,col,color = im.shape
    im_bl=np.zeros((int(row*col/1024),32,32,3)).astype(np.float32)
    count=0
    for i in range(0,row-row%32,32):
        for j in range(0,col-col%32,32):
            im_bl[count,:,:,:]=im[i:i+32,j:j+32,:]
            count = count +1
    im_bl=im_bl/255.
    return im_bl

def block2img(img_blocks,img_size):
    
    row,col = img_size
    img=np.zeros((row,col,3)).astype(np.float32)
    n,k,l,c=img_blocks.shape
                 
    for i in range(0,int(row/k)):
        for j in range(0,int(col/k)):
            img[i*k:(i+1)*k,j*l:(j+1)*l,:]=img_blocks[int(i*col/k+j),:,:,:]
    return img

lena_img = skimage.io.imread('../test_img_old/lena512color.tiff')

lena_32=img2block(lena_img)


'''
bu_img_recon=block2img(bu_img_32,(672,1024))
bu_img_recon = (bu_img_recon*255.).astype(np.uint8)
skimage.io.imshow(bu_img)
skimage.io.show()
skimage.io.imshow(bu_img_recon)
skimage.io.show()
#skimage.io.imsave('../test_img/bu2010_recon.tif',bu_img_recon)
''''
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-51525da06a15> in <module>()
#      33
#      34
# ---> 35 bu_img_recon=block2img(bu_img_32,(672,1024))
#      36 bu_img_recon = (bu_img_recon*255.).astype(np.uint8)
#      37 skimage.io.imshow(bu_img)
#
# NameError: name 'bu_img_32' is not defined

# %%
def convert2uint8(img):
    img[img>255]=255
    img[img<0]=0
    return img.astype(np.uint8)

# %% [markdown]
# # Part-2 - CNN

# %%
x_tr = cf10_tr_img.astype(np.float32)#*255.
x_test = cf10_test_img.astype(np.float32)#*255.
x_test=x_test[:200,:,:,:]
img = skimage.io.imread('../test_img_old/lena512color.tiff')
img_32=img2block(img)
#print(lion_32.shape)
outname='/tmp/cnn_autoencoder'
a=outname+'FT'
print(outname)
print(a)
# Out:
# /tmp/cnn_autoencoder
# /tmp/cnn_autoencoderFT

# %%
def cnn_autoencoder(x_,kernels1=[5,7],kernels2=[7,5],filters1=[16,128],filters2=[128,3],pool_size=[1,2,2,1]):
    out_=x_
    for k in range(len(kernels1)):
        conv = tf.layers.conv2d(inputs=out_,
                                filters=filters1[k],
                                kernel_size=[kernels1[k],kernels1[k]],
                                padding="same",
                                activation=tf.nn.relu,
                                name='conv'+str(k))
        pool_now=pool_size[k]
        if(pool_now==1):
            out_=conv
        else:
            out_ = tf.layers.max_pooling2d(inputs=conv, 
                                           pool_size=[pool_now,pool_now], 
                                           strides=pool_now,
                                           name = 'pool'+str(k))
        
        out_quant=tf.round(out_*255.)/255.

    for k in range(len(kernels2)):
        with tf.variable_scope("deconv") as var_scope:
            pool_now=pool_size[k+len(kernels1)]
            if(pool_now==1):
                x_up=out_
                out_ = tf.layers.conv2d(inputs=x_up,
                                        filters=filters2[k],
                                        kernel_size=[kernels2[k],kernels2[k]],
                                        padding="same",
                                        activation=tf.nn.relu,
                                        name='deconv'+str(k))
                var_scope.reuse_variables() 
                x_quant_up=out_quant
                out_quant = tf.layers.conv2d(inputs=x_quant_up,
                                            filters=filters2[k],
                                            kernel_size=[kernels2[k],kernels2[k]],
                                            padding="same",
                                            activation=tf.nn.relu,
                                            name='deconv'+str(k))
            else:
                sh = out_.get_shape().as_list()
                x_up=tf.image.resize_images(out_,[sh[1]*pool_now,sh[2]*pool_now])
                out_ = tf.layers.conv2d(inputs=x_up,
                                        filters=filters2[k],
                                        kernel_size=[kernels2[k],kernels2[k]],
                                        padding="same",
                                        activation=tf.nn.relu,
                                        name='deconv'+str(k))
                var_scope.reuse_variables() 
                x_quant_up=tf.image.resize_images(out_quant,[sh[1]*pool_now,sh[2]*pool_now])
                out_quant = tf.layers.conv2d(inputs=x_quant_up,
                                            filters=filters2[k],
                                            kernel_size=[kernels2[k],kernels2[k]],
                                            padding="same",
                                            activation=tf.nn.relu,
                                            name='deconv'+str(k))


    return out_,out_quant

# %%
#HVS matrix implementation
import scipy.fftpack as fft
f=np.linspace(1.0, 40.0, num=32)
h=2.6*(0.0192+0.114*f)*np.exp(-np.power((0.114*f),1.1)).reshape([1,-1])
H=np.matmul(np.ones((32,1)),h)
H2=(H*H.T).astype(np.float32)
print(H2)
h2 = fft.dct(fft.dct(H2,type=3,norm='ortho').T,type=3,norm='ortho')
h3=np.zeros((32,32,3,1)).astype(np.float32)
h3[:,:,0,0]=h2
h3[:,:,1,0]=h2
h3[:,:,2,0]=h2


print(h2)
print(h3)
# Out:
# [[ 0.09983069  0.18150099  0.23934336 ...,  0.02520034  0.02169322
#    0.01864358]
#  [ 0.18150099  0.32998478  0.43514732 ...,  0.04581644  0.03944018
#    0.03389566]
#  [ 0.23934336  0.43514732  0.57382399 ...,  0.06041763  0.05200934
#    0.04469784]
#  ...,
#  [ 0.02520034  0.04581644  0.06041763 ...,  0.00636134  0.00547604
#    0.00470621]
#  [ 0.02169322  0.03944018  0.05200934 ...,  0.00547604  0.00471394
#    0.00405125]
#  [ 0.01864358  0.03389566  0.04469784 ...,  0.00470621  0.00405125
#    0.00348172]]
# [[  1.00616789e+01   1.49537575e+00  -8.23408246e-01 ...,  -1.08088404e-02
#    -6.29915297e-03  -7.97748566e-03]
#  [  1.49537563e+00   2.22244024e-01  -1.22375660e-01 ...,  -1.60639174e-03
#    -9.36212018e-04  -1.18559599e-03]
#  [ -8.23408127e-01  -1.22375637e-01   6.73845112e-02 ...,   8.84542242e-04
#     5.15500084e-04   6.52849674e-04]
#  ...,
#  [ -1.08086262e-02  -1.60637801e-03   8.84536712e-04 ...,   1.16189622e-05
#     6.77026401e-06   8.54581594e-06]
#  [ -6.29931595e-03  -9.36207653e-04   5.15490246e-04 ...,   6.73490285e-06
#     3.93982918e-06   5.02169132e-06]
#  [ -7.97758996e-03  -1.18559599e-03   6.52898801e-04 ...,   8.68059578e-06
#     5.00350143e-06   6.26919791e-06]]
# [[[[  1.00616789e+01]
#    [  1.00616789e+01]
#    [  1.00616789e+01]]
#
#   [[  1.49537575e+00]
#    [  1.49537575e+00]
#    [  1.49537575e+00]]
#
#   [[ -8.23408246e-01]
#    [ -8.23408246e-01]
#    [ -8.23408246e-01]]
#
#   ...,
#   [[ -1.08088404e-02]
#    [ -1.08088404e-02]
#    [ -1.08088404e-02]]
#
#   [[ -6.29915297e-03]
#    [ -6.29915297e-03]
#    [ -6.29915297e-03]]
#
#   [[ -7.97748566e-03]
#    [ -7.97748566e-03]
#    [ -7.97748566e-03]]]
#
#
#  [[[  1.49537563e+00]
#    [  1.49537563e+00]
#    [  1.49537563e+00]]
#
#   [[  2.22244024e-01]
#    [  2.22244024e-01]
#    [  2.22244024e-01]]
#
#   [[ -1.22375660e-01]
#    [ -1.22375660e-01]
#    [ -1.22375660e-01]]
#
#   ...,
#   [[ -1.60639174e-03]
#    [ -1.60639174e-03]
#    [ -1.60639174e-03]]
#
#   [[ -9.36212018e-04]
#    [ -9.36212018e-04]
#    [ -9.36212018e-04]]
#
#   [[ -1.18559599e-03]
#    [ -1.18559599e-03]
#    [ -1.18559599e-03]]]
#
#
#  [[[ -8.23408127e-01]
#    [ -8.23408127e-01]
#    [ -8.23408127e-01]]
#
#   [[ -1.22375637e-01]
#    [ -1.22375637e-01]
#    [ -1.22375637e-01]]
#
#   [[  6.73845112e-02]
#    [  6.73845112e-02]
#    [  6.73845112e-02]]
#
#   ...,
#   [[  8.84542242e-04]
#    [  8.84542242e-04]
#    [  8.84542242e-04]]
#
#   [[  5.15500084e-04]
#    [  5.15500084e-04]
#    [  5.15500084e-04]]
#
#   [[  6.52849674e-04]
#    [  6.52849674e-04]
#    [  6.52849674e-04]]]
#
#
#  ...,
#  [[[ -1.08086262e-02]
#    [ -1.08086262e-02]
#    [ -1.08086262e-02]]
#
#   [[ -1.60637801e-03]
#    [ -1.60637801e-03]
#    [ -1.60637801e-03]]
#
#   [[  8.84536712e-04]
#    [  8.84536712e-04]
#    [  8.84536712e-04]]
#
#   ...,
#   [[  1.16189622e-05]
#    [  1.16189622e-05]
#    [  1.16189622e-05]]
#
#   [[  6.77026401e-06]
#    [  6.77026401e-06]
#    [  6.77026401e-06]]
#
#   [[  8.54581594e-06]
#    [  8.54581594e-06]
#    [  8.54581594e-06]]]
#
#
#  [[[ -6.29931595e-03]
#    [ -6.29931595e-03]
#    [ -6.29931595e-03]]
#
#   [[ -9.36207653e-04]
#    [ -9.36207653e-04]
#    [ -9.36207653e-04]]
#
#   [[  5.15490246e-04]
#    [  5.15490246e-04]
#    [  5.15490246e-04]]
#
#   ...,
#   [[  6.73490285e-06]
#    [  6.73490285e-06]
#    [  6.73490285e-06]]
#
#   [[  3.93982918e-06]
#    [  3.93982918e-06]
#    [  3.93982918e-06]]
#
#   [[  5.02169132e-06]
#    [  5.02169132e-06]
#    [  5.02169132e-06]]]
#
#
#  [[[ -7.97758996e-03]
#    [ -7.97758996e-03]
#    [ -7.97758996e-03]]
#
#   [[ -1.18559599e-03]
#    [ -1.18559599e-03]
#    [ -1.18559599e-03]]
#
#   [[  6.52898801e-04]
#    [  6.52898801e-04]
#    [  6.52898801e-04]]
#
#   ...,
#   [[  8.68059578e-06]
#    [  8.68059578e-06]
#    [  8.68059578e-06]]
#
#   [[  5.00350143e-06]
#    [  5.00350143e-06]
#    [  5.00350143e-06]]
#
#   [[  6.26919791e-06]
#    [  6.26919791e-06]
#    [  6.26919791e-06]]]]

# %%
#Working
def apply_classification_loss_mse(kernels1=[5,7],kernels2=[7,5],
                                 filters1=[16,128],filters2=[128,3],
                                pool_size=[2,2],learning_rate=1.,FT=False):
    with tf.Graph().as_default() as g:
        with tf.device("/gpu:0"):  # use gpu:0 if on GPU
            x_ = tf.placeholder(tf.float32, [None, 32, 32, 3])
            (x_out,x_out_quant)=cnn_autoencoder(x_,pool_size=pool_size,kernels1=kernels1,filters1=filters1,
                                kernels2=kernels2,filters2=filters2)

            #y_dict = dict(labels=y_, logits=y_logits)
            #losses = tf.nn.sparse_softmax_cross_entropy_with_logits(**y_dict)
            #cross_entropy_loss = tf.reduce_mean(losses)
            mse_loss1=tf.reduce_mean(tf.subtract(x_,x_out)**2)
            #a=tf.pad(tf.subtract(x_,x_out),[[0,0],[16,16],[16,16],[0,0]],'CONSTANT')

            #mse_loss1=tf.reduce_mean(tf.nn.conv2d(a,h3,strides=[1,1,1,1],padding="VALID")**2)
            mse_loss2=tf.reduce_mean(tf.subtract(x_,x_out_quant)**2)
            trainer = tf.train.AdamOptimizer(learning_rate=learning_rate)
            if(FT):
                with tf.variable_scope('deconv', reuse=True) as vs:
                    var_list=[v for v in tf.global_variables() if v.name.startswith(vs.name)]
                train_op = trainer.minimize(mse_loss1,var_list=var_list)
            else:
                train_op = trainer.minimize(mse_loss1)

            #y_pred = tf.argmax(tf.nn.softmax(y_logits), dimension=1)
            #correct_prediction = tf.equal(tf.cast(y_pred, tf.int32), y_)
            #accuracy = tf.reduce_mean(tf.cast(correct_prediction, tf.float32))

    model_dict = {'graph': g, 'inputs': x_,'outputs':x_out_quant, 'train_op': train_op, 'loss1': mse_loss1,'loss2': mse_loss2}
    
    return model_dict

# %%
#In progress
def apply_classification_loss_ssim(kernels1=[5,7],kernels2=[7,5],
                                 filters1=[16,128],filters2=[128,3],
                                pool_size=[2,2],learning_rate=1.):
    with tf.Graph().as_default() as g:
        with tf.device("/gpu:0"):  # use gpu:0 if on GPU
            x_ = tf.placeholder(tf.float32, [None, 32, 32, 3])
            (x_out,x_out_quant)=cnn_autoencoder(x_,pool_size=pool_size,kernels1=kernels1,filters1=filters1,
                                kernels2=kernels2,filters2=filters2)

            #y_dict = dict(labels=y_, logits=y_logits)
            #losses = tf.nn.sparse_softmax_cross_entropy_with_logits(**y_dict)
            #cross_entropy_loss = tf.reduce_mean(losses)
            mse_loss1=tf.reduce_mean(tf.subtract(x_,x_out)**2)
            #a=tf.pad(tf.subtract(x_,x_out),[[0,0],[16,16],[16,16],[0,0]],'CONSTANT')

            #mse_loss1=tf.reduce_mean(tf.nn.conv2d(a,h3,strides=[1,1,1,1],padding="VALID")**2)
            mse_loss2=tf.reduce_mean(tf.subtract(x_,x_out_quant)**2)
            trainer = tf.train.AdamOptimizer(learning_rate=learning_rate)
            train_op = trainer.minimize(mse_loss1)

            #y_pred = tf.argmax(tf.nn.softmax(y_logits), dimension=1)
            #correct_prediction = tf.equal(tf.cast(y_pred, tf.int32), y_)
            #accuracy = tf.reduce_mean(tf.cast(correct_prediction, tf.float32))

    model_dict = {'graph': g, 'inputs': x_,'outputs':x_out_quant, 'train_op': train_op, 'loss1': mse_loss1,'loss2': mse_loss2}
    
    return model_dict

# %%
def train_model(model_dict, dataset_generators, train_every=100, test_every=200, load=False,
                learning_rate=1.,fname='cifar10_recon',outname='/tmp/cnn_autoencoder',ftname='/tmp/cnn_autoencoder'):
    with model_dict['graph'].as_default(), tf.Session() as sess:
        sess.run(tf.global_variables_initializer())
        
        
        
        
        
        ### WORK ON IT NOT TOO HARD
        saver=tf.train.Saver()
        if(load):
            saver.restore(sess, outname)
            print("Model loaded")
        else:
            sess.run(tf.global_variables_initializer())
        
        ids=[i for i in range(100)]
        for iter_i in range(100000):
            batch_xs = x_tr[ids,:,:,:] 
            ids=[(ids[0]+100+i)%x_tr.shape[0] for i in range(100)]
            sess.run(model_dict['train_op'], feed_dict={model_dict['inputs']: batch_xs})
            
            # test trained model
            if iter_i % train_every == 0:
                tf_feed_dict = {model_dict['inputs']: batch_xs}
                loss_val = sess.run(model_dict['loss1'], feed_dict={model_dict['inputs']: batch_xs})
                print('iteration %d\t train mse: %.3E\t'%(iter_i,loss_val))
                if iter_i % test_every == 0:
                    #tf_feed_dict = {x_: x_test}
                    loss_val1 = sess.run(model_dict['loss1'], feed_dict={model_dict['inputs']: x_test})
                    loss_val2 = sess.run(model_dict['loss2'], feed_dict={model_dict['inputs']: x_test})
                    print('iteration %d\t TEST MSE: %.3E\t TEST MSE(Quantized): %.3E\t'%(iter_i,loss_val1,loss_val2))
                    
                    
                    lena_block=sess.run(model_dict['outputs'], 
                                       feed_dict={model_dict['inputs']:lena_32})
                    x_from_test=sess.run(model_dict['outputs'], 
                                         feed_dict={model_dict['inputs']:x_test[:5,:,:,:].reshape([-1,32,32,3])})
                    
                    lena_recon=block2img(lena_block,(512,512))
                    lena_recon = convert2uint8(lena_recon*255.)
                    skimage.io.imsave('../'+fname+'/lena4_'+str(int(iter_i/test_every))+'.tiff',lena_recon)

                    for i in range(2):
                        img_recon=convert2uint8((255*x_from_test[i,:,:,:]).reshape([32,32,3])).astype(np.uint8)
                        skimage.io.imsave('../'+fname+'/test'+str(i)+'_'+str(int(iter_i/test_every))+'.tiff',img_recon)
                        
        saver = tf.train.Saver()
        if(load):
            outname=ftname
        save_path = saver.save(sess, outname)
        print("Model saved in file: %s" % save_path)
        return saver

# %%
tf.reset_default_graph()
model_dict=apply_classification_loss_mse(kernels1=[5,7,9],kernels2=[9,7,5],
                                     filters1=[64,16,3],filters2=[3,3,3],
                                     pool_size=[1,2,2,2,2,1],learning_rate=7e-5)
saver = train_model(model_dict, [], train_every=100, test_every=2000,load=False,
                    fname='cifar10_recon0',outname='/tmp/cnnx4_test0')

# %%
tf.reset_default_graph()
model_dict=apply_classification_loss_mse(kernels1=[5,7,9],kernels2=[9,7,5],
                                     filters1=[64,16,3],filters2=[64,16,3],
                                     pool_size=[1,2,2,2,2,1],learning_rate=7e-5)
saver = train_model(model_dict, [], train_every=100, test_every=2000,load=False,
                    fname='cifar10_recon0',outname='/tmp/cnnx4_test0')
# Out:
# iteration 0	 train mse: 2.062E-01
# iteration 0	 TEST MSE: 2.353E-01	 TEST MSE(Quantized): 2.353E-01
# iteration 100	 train mse: 1.615E-02
# iteration 200	 train mse: 1.129E-02
# iteration 99700	 train mse: 3.940E-04
# iteration 99800	 train mse: 5.041E-04
# iteration 99900	 train mse: 4.748E-04
# Model saved in file: /tmp/cnnx4_test0

# %%
tf.reset_default_graph()
model_dict=apply_classification_loss_mse(kernels1=[5,5,5],kernels2=[5,5,5],
                                     filters1=[16,20,20],filters2=[20,16,3],
                                     pool_size=[1,2,2,2,2,1],learning_rate=0.0001)
saver = train_model(model_dict, [], train_every=100, test_every=2000,load=False,
                    fname='cifar10_recon1',outname='/tmp/cnnx4_test1')
# Out:
# iteration 0	 train mse: 2.606E-01
# iteration 0	 TEST MSE: 2.958E-01	 TEST MSE(Quantized): 2.958E-01
# /home/mtezcan/anaconda3/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: ../cifar10_recon1/lena4_0.tiff is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/mtezcan/anaconda3/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: ../cifar10_recon1/test0_0.tiff is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/mtezcan/anaconda3/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: ../cifar10_recon1/test1_0.tiff is a low contrast image
#   warn('%s is a low contrast image' % fname)
# iteration 100	 train mse: 3.853E-02
# iteration 200	 train mse: 1.683E-02
# iteration 300	 train mse: 1.382E-02
# iteration 400	 train mse: 1.197E-02
# iteration 500	 train mse: 1.148E-02
# iteration 600	 train mse: 8.342E-03
# iteration 700	 train mse: 8.427E-03
# iteration 800	 train mse: 8.820E-03
# iteration 900	 train mse: 8.480E-03
# iteration 1000	 train mse: 8.605E-03
# iteration 1100	 train mse: 6.760E-03
# iteration 1200	 train mse: 6.975E-03
# iteration 1300	 train mse: 7.534E-03
# iteration 1400	 train mse: 7.417E-03
# iteration 1500	 train mse: 7.625E-03
# iteration 1600	 train mse: 6.095E-03
# iteration 1700	 train mse: 6.261E-03
# iteration 1800	 train mse: 6.843E-03
# iteration 1900	 train mse: 6.791E-03
# iteration 2000	 train mse: 7.021E-03
# iteration 2000	 TEST MSE: 6.224E-03	 TEST MSE(Quantized): 6.225E-03
# iteration 2100	 train mse: 5.702E-03
# iteration 2200	 train mse: 5.831E-03
# iteration 2300	 train mse: 6.413E-03
# iteration 2400	 train mse: 6.383E-03
# iteration 2500	 train mse: 6.613E-03
# iteration 2600	 train mse: 5.416E-03
# iteration 2700	 train mse: 5.511E-03
# iteration 2800	 train mse: 6.086E-03
# iteration 2900	 train mse: 6.077E-03
# iteration 3000	 train mse: 6.274E-03
# iteration 3100	 train mse: 5.191E-03
# iteration 3200	 train mse: 5.263E-03
# iteration 3300	 train mse: 5.831E-03
# iteration 3400	 train mse: 5.837E-03
# iteration 3500	 train mse: 6.008E-03
# iteration 3600	 train mse: 5.016E-03
# iteration 3700	 train mse: 5.070E-03
# iteration 3800	 train mse: 5.640E-03
# iteration 3900	 train mse: 5.642E-03
# iteration 4000	 train mse: 5.795E-03
# iteration 4000	 TEST MSE: 5.213E-03	 TEST MSE(Quantized): 5.213E-03
# iteration 4100	 train mse: 4.862E-03
# iteration 4200	 train mse: 4.908E-03
# iteration 4300	 train mse: 5.464E-03
# iteration 4400	 train mse: 5.470E-03
# iteration 4500	 train mse: 5.620E-03
# iteration 4600	 train mse: 4.736E-03
# iteration 4700	 train mse: 4.763E-03
# iteration 4800	 train mse: 5.327E-03
# iteration 18100	 train mse: 3.214E-03
# iteration 18200	 train mse: 3.177E-03
# iteration 18300	 train mse: 3.561E-03
# iteration 18400	 train mse: 3.605E-03
# iteration 18500	 train mse: 3.763E-03
# iteration 18600	 train mse: 3.191E-03
# iteration 18700	 train mse: 3.154E-03
# iteration 18800	 train mse: 3.533E-03
# iteration 18900	 train mse: 3.580E-03
# iteration 19000	 train mse: 3.736E-03
# iteration 19100	 train mse: 3.168E-03
# iteration 19200	 train mse: 3.133E-03
# iteration 19300	 train mse: 3.503E-03
# iteration 19400	 train mse: 3.555E-03
# iteration 19500	 train mse: 3.708E-03
# iteration 19600	 train mse: 3.146E-03
# iteration 19700	 train mse: 3.111E-03
# iteration 19800	 train mse: 3.477E-03
# iteration 19900	 train mse: 3.530E-03
# Model saved in file: /tmp/cnnx4_test1

# %%
tf.reset_default_graph()
model_dict=apply_classification_loss_mse(kernels1=[5,5,5],kernels2=[5,5,5],
                                     filters1=[64,64,64],filters2=[64,64,3],
                                     pool_size=[1,2,2,2,2,1],learning_rate=0.0001)
saver = train_model(model_dict, [], train_every=100, test_every=2000,load=False,
                    fname='cifar10_recon2',outname='/tmp/cnnx4_test2')
# Out:
# iteration 0	 train mse: 2.264E-01
# iteration 0	 TEST MSE: 2.577E-01	 TEST MSE(Quantized): 2.577E-01
# /home/mtezcan/anaconda3/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: ../cifar10_recon2/lena4_0.tiff is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/mtezcan/anaconda3/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: ../cifar10_recon2/test0_0.tiff is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/mtezcan/anaconda3/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: ../cifar10_recon2/test1_0.tiff is a low contrast image
#   warn('%s is a low contrast image' % fname)
# iteration 100	 train mse: 1.202E-02
# iteration 200	 train mse: 8.695E-03
# iteration 300	 train mse: 7.953E-03
# iteration 400	 train mse: 7.018E-03
# iteration 500	 train mse: 6.768E-03
# iteration 600	 train mse: 5.333E-03
# iteration 700	 train mse: 5.125E-03
# iteration 800	 train mse: 5.486E-03
# iteration 900	 train mse: 5.352E-03
# iteration 1000	 train mse: 5.343E-03
# iteration 1100	 train mse: 4.352E-03
# iteration 1200	 train mse: 4.276E-03
# iteration 1300	 train mse: 4.830E-03
# iteration 1400	 train mse: 4.678E-03
# iteration 1500	 train mse: 4.669E-03
# iteration 1600	 train mse: 3.853E-03
# iteration 1700	 train mse: 3.780E-03
# iteration 1800	 train mse: 4.318E-03
# iteration 1900	 train mse: 4.352E-03
# iteration 2000	 train mse: 4.221E-03
# iteration 2000	 TEST MSE: 3.847E-03	 TEST MSE(Quantized): 3.847E-03
# iteration 2100	 train mse: 3.531E-03
# iteration 2200	 train mse: 3.429E-03
# iteration 2300	 train mse: 3.944E-03
# iteration 2400	 train mse: 3.842E-03
# iteration 2500	 train mse: 3.874E-03
# iteration 2600	 train mse: 3.237E-03
# iteration 2700	 train mse: 3.145E-03
# iteration 2800	 train mse: 3.564E-03
# iteration 2900	 train mse: 3.548E-03
# iteration 3000	 train mse: 3.616E-03
# iteration 3100	 train mse: 3.003E-03
# iteration 3200	 train mse: 2.949E-03
# iteration 3300	 train mse: 3.292E-03
# iteration 3400	 train mse: 3.354E-03
# iteration 16700	 train mse: 1.433E-03
# iteration 16800	 train mse: 1.608E-03
# iteration 16900	 train mse: 1.695E-03
# iteration 17000	 train mse: 1.856E-03
# iteration 17100	 train mse: 1.538E-03
# iteration 17200	 train mse: 1.441E-03
# iteration 17300	 train mse: 1.588E-03
# iteration 17400	 train mse: 1.679E-03
# iteration 17500	 train mse: 1.806E-03
# iteration 17600	 train mse: 1.518E-03
# iteration 17700	 train mse: 1.431E-03
# iteration 17800	 train mse: 1.578E-03
# iteration 17900	 train mse: 1.692E-03
# iteration 18000	 train mse: 1.719E-03
# iteration 18000	 TEST MSE: 1.599E-03	 TEST MSE(Quantized): 1.600E-03
# iteration 18100	 train mse: 1.597E-03
# iteration 18200	 train mse: 1.398E-03
# iteration 18300	 train mse: 1.696E-03
# iteration 18400	 train mse: 1.636E-03
# iteration 18500	 train mse: 1.706E-03
# iteration 18600	 train mse: 1.590E-03
# iteration 18700	 train mse: 1.384E-03
# iteration 18800	 train mse: 1.805E-03
# iteration 18900	 train mse: 1.709E-03
# iteration 19000	 train mse: 1.688E-03
# iteration 19100	 train mse: 1.470E-03
# iteration 19200	 train mse: 1.420E-03
# iteration 19300	 train mse: 1.521E-03
# iteration 19400	 train mse: 1.605E-03
# iteration 19500	 train mse: 1.751E-03
# iteration 19600	 train mse: 1.694E-03
# iteration 19700	 train mse: 1.344E-03
# iteration 19800	 train mse: 1.528E-03
# iteration 19900	 train mse: 1.587E-03
# Model saved in file: /tmp/cnnx4_test2

# %%
tf.reset_default_graph()
model_dict=apply_classification_loss_mse(kernels1=[3,3,3],kernels2=[3,3,3],
                                     filters1=[64,64,64],filters2=[64,64,3],
                                     pool_size=[1,2,2,2,2,1],learning_rate=0.0001)
saver = train_model(model_dict, [], train_every=100, test_every=2000,load=False,
                    fname='cifar10_recon3',outname='/tmp/cnnx4_test3')
# Out:
# iteration 0	 train mse: 2.424E-01
# iteration 0	 TEST MSE: 2.749E-01	 TEST MSE(Quantized): 2.749E-01
# /home/mtezcan/anaconda3/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: ../cifar10_recon3/lena4_0.tiff is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/mtezcan/anaconda3/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: ../cifar10_recon3/test0_0.tiff is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/mtezcan/anaconda3/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: ../cifar10_recon3/test1_0.tiff is a low contrast image
#   warn('%s is a low contrast image' % fname)
# iteration 100	 train mse: 2.164E-02
# iteration 200	 train mse: 9.924E-03
# iteration 300	 train mse: 8.607E-03
# iteration 400	 train mse: 7.657E-03
# iteration 500	 train mse: 7.297E-03
# iteration 600	 train mse: 5.629E-03
# iteration 700	 train mse: 5.594E-03
# iteration 800	 train mse: 5.953E-03
# iteration 900	 train mse: 5.774E-03
# iteration 1000	 train mse: 5.817E-03
# iteration 1100	 train mse: 4.761E-03
# iteration 1200	 train mse: 4.738E-03
# iteration 1300	 train mse: 5.109E-03
# iteration 1400	 train mse: 5.022E-03
# iteration 1500	 train mse: 5.077E-03
# iteration 1600	 train mse: 4.176E-03
# iteration 1700	 train mse: 4.134E-03
# iteration 1800	 train mse: 4.513E-03
# iteration 1900	 train mse: 4.464E-03
# iteration 2000	 train mse: 4.525E-03
# iteration 2000	 TEST MSE: 4.093E-03	 TEST MSE(Quantized): 4.095E-03
# iteration 2100	 train mse: 3.741E-03
# iteration 2200	 train mse: 3.698E-03
# iteration 2300	 train mse: 4.110E-03
# iteration 2400	 train mse: 4.042E-03
# iteration 2500	 train mse: 4.119E-03
# iteration 2600	 train mse: 3.435E-03
# iteration 2700	 train mse: 3.380E-03
# iteration 2800	 train mse: 3.795E-03
# iteration 2900	 train mse: 3.741E-03
# iteration 3000	 train mse: 3.831E-03
# iteration 3100	 train mse: 3.209E-03
# iteration 3200	 train mse: 3.144E-03
# iteration 3300	 train mse: 3.536E-03
# iteration 3400	 train mse: 3.514E-03
# iteration 3500	 train mse: 3.620E-03
# iteration 3600	 train mse: 3.021E-03
# iteration 3700	 train mse: 2.960E-03
# iteration 3800	 train mse: 3.354E-03
# iteration 3900	 train mse: 3.334E-03
# iteration 4000	 train mse: 3.430E-03
# iteration 4000	 TEST MSE: 3.130E-03	 TEST MSE(Quantized): 3.130E-03
# iteration 4100	 train mse: 2.884E-03
# iteration 4200	 train mse: 2.813E-03
# iteration 4300	 train mse: 3.214E-03
# iteration 4400	 train mse: 3.189E-03
# iteration 4500	 train mse: 3.276E-03
# iteration 4600	 train mse: 2.760E-03
# iteration 4700	 train mse: 2.692E-03
# iteration 4800	 train mse: 3.038E-03
# iteration 4900	 train mse: 3.107E-03
# iteration 5000	 train mse: 3.152E-03
# iteration 5100	 train mse: 2.670E-03
# iteration 5200	 train mse: 2.583E-03
# iteration 5300	 train mse: 3.052E-03
# iteration 5400	 train mse: 2.941E-03
# iteration 5500	 train mse: 3.057E-03
# iteration 5600	 train mse: 2.575E-03
# iteration 5700	 train mse: 2.496E-03
# iteration 5800	 train mse: 2.851E-03
# iteration 5900	 train mse: 2.918E-03
# iteration 6000	 train mse: 2.953E-03
# iteration 6000	 TEST MSE: 2.705E-03	 TEST MSE(Quantized): 2.705E-03
# iteration 6100	 train mse: 2.505E-03
# iteration 6200	 train mse: 2.423E-03
# iteration 6300	 train mse: 2.834E-03
# iteration 6400	 train mse: 2.769E-03
# iteration 6500	 train mse: 2.876E-03
# iteration 6600	 train mse: 2.437E-03
# iteration 6700	 train mse: 2.362E-03
# iteration 6800	 train mse: 2.716E-03
# iteration 6900	 train mse: 2.735E-03
# iteration 7000	 train mse: 2.799E-03
# iteration 7100	 train mse: 2.390E-03
# iteration 7200	 train mse: 2.301E-03
# iteration 7300	 train mse: 2.654E-03
# iteration 7400	 train mse: 2.665E-03
# iteration 7500	 train mse: 2.733E-03
# iteration 7600	 train mse: 2.345E-03
# iteration 7700	 train mse: 2.270E-03
# iteration 7800	 train mse: 2.611E-03
# iteration 7900	 train mse: 2.589E-03
# iteration 8000	 train mse: 2.671E-03
# iteration 8000	 TEST MSE: 2.452E-03	 TEST MSE(Quantized): 2.453E-03
# iteration 8100	 train mse: 2.299E-03
# iteration 8200	 train mse: 2.223E-03
# iteration 8300	 train mse: 2.540E-03
# iteration 8400	 train mse: 2.551E-03
# iteration 8500	 train mse: 2.624E-03
# iteration 8600	 train mse: 2.239E-03
# iteration 8700	 train mse: 2.172E-03
# iteration 8800	 train mse: 2.493E-03
# iteration 8900	 train mse: 2.500E-03
# iteration 9000	 train mse: 2.572E-03
# iteration 9100	 train mse: 2.216E-03
# iteration 9200	 train mse: 2.132E-03
# iteration 9300	 train mse: 2.386E-03
# iteration 9400	 train mse: 2.433E-03
# iteration 9500	 train mse: 2.541E-03
# iteration 9600	 train mse: 2.174E-03
# iteration 9700	 train mse: 2.090E-03
# iteration 9800	 train mse: 2.349E-03
# iteration 9900	 train mse: 2.398E-03
# iteration 10000	 train mse: 2.496E-03
# iteration 10000	 TEST MSE: 2.297E-03	 TEST MSE(Quantized): 2.298E-03
# iteration 10100	 train mse: 2.141E-03
# iteration 10200	 train mse: 2.055E-03
# iteration 10300	 train mse: 2.281E-03
# iteration 10400	 train mse: 2.380E-03
# iteration 10500	 train mse: 2.454E-03
# iteration 10600	 train mse: 2.098E-03
# iteration 10700	 train mse: 2.017E-03
# iteration 10800	 train mse: 2.237E-03
# iteration 10900	 train mse: 2.348E-03
# iteration 11000	 train mse: 2.414E-03
# iteration 11100	 train mse: 2.058E-03
# iteration 11200	 train mse: 1.978E-03
# iteration 11300	 train mse: 2.210E-03
# iteration 11400	 train mse: 2.300E-03
# iteration 11500	 train mse: 2.377E-03
# iteration 11600	 train mse: 2.018E-03
# iteration 11700	 train mse: 1.939E-03
# iteration 11800	 train mse: 2.177E-03
# iteration 11900	 train mse: 2.276E-03
# iteration 12000	 train mse: 2.334E-03
# iteration 12000	 TEST MSE: 2.153E-03	 TEST MSE(Quantized): 2.154E-03
# iteration 12100	 train mse: 1.984E-03
# iteration 12200	 train mse: 1.915E-03
# iteration 12300	 train mse: 2.133E-03
# iteration 12400	 train mse: 2.244E-03
# iteration 12500	 train mse: 2.296E-03
# iteration 12600	 train mse: 1.956E-03
# iteration 12700	 train mse: 1.890E-03
# iteration 12800	 train mse: 2.103E-03
# iteration 12900	 train mse: 2.212E-03
# iteration 13000	 train mse: 2.264E-03
# iteration 13100	 train mse: 1.931E-03
# iteration 13200	 train mse: 1.865E-03
# iteration 13300	 train mse: 2.075E-03
# iteration 13400	 train mse: 2.184E-03
# iteration 13500	 train mse: 2.234E-03
# iteration 13600	 train mse: 1.908E-03
# iteration 13700	 train mse: 1.841E-03
# iteration 13800	 train mse: 2.048E-03
# iteration 13900	 train mse: 2.157E-03
# iteration 14000	 train mse: 2.204E-03
# iteration 14000	 TEST MSE: 2.032E-03	 TEST MSE(Quantized): 2.033E-03
# iteration 14100	 train mse: 1.889E-03
# iteration 14200	 train mse: 1.818E-03
# iteration 14300	 train mse: 2.022E-03
# iteration 14400	 train mse: 2.135E-03
# iteration 14500	 train mse: 2.175E-03
# iteration 14600	 train mse: 1.864E-03
# iteration 14700	 train mse: 1.795E-03
# iteration 14800	 train mse: 1.999E-03
# iteration 14900	 train mse: 2.109E-03
# iteration 15000	 train mse: 2.149E-03
# iteration 15100	 train mse: 1.842E-03
# iteration 15200	 train mse: 1.775E-03
# iteration 15300	 train mse: 1.977E-03
# iteration 15400	 train mse: 2.088E-03
# iteration 15500	 train mse: 2.125E-03
# iteration 15600	 train mse: 1.826E-03
# iteration 15700	 train mse: 1.746E-03
# iteration 15800	 train mse: 1.959E-03
# iteration 15900	 train mse: 2.066E-03
# iteration 16000	 train mse: 2.104E-03
# iteration 16000	 TEST MSE: 1.939E-03	 TEST MSE(Quantized): 1.940E-03
# iteration 16100	 train mse: 1.808E-03
# iteration 16200	 train mse: 1.729E-03
# iteration 16300	 train mse: 1.938E-03
# iteration 16400	 train mse: 2.045E-03
# iteration 16500	 train mse: 2.084E-03
# iteration 16600	 train mse: 1.785E-03
# iteration 16700	 train mse: 1.728E-03
# iteration 16800	 train mse: 1.919E-03
# iteration 16900	 train mse: 2.021E-03
# iteration 17000	 train mse: 2.065E-03
# iteration 17100	 train mse: 1.772E-03
# iteration 17200	 train mse: 1.703E-03
# iteration 17300	 train mse: 1.899E-03
# iteration 17400	 train mse: 2.006E-03
# iteration 17500	 train mse: 2.048E-03
# iteration 17600	 train mse: 1.765E-03
# iteration 17700	 train mse: 1.683E-03
# iteration 17800	 train mse: 1.885E-03
# iteration 17900	 train mse: 1.986E-03
# iteration 18000	 train mse: 2.030E-03
# iteration 18000	 TEST MSE: 1.870E-03	 TEST MSE(Quantized): 1.871E-03
# iteration 18100	 train mse: 1.741E-03
# iteration 18200	 train mse: 1.671E-03
# iteration 18300	 train mse: 1.867E-03
# iteration 18400	 train mse: 1.966E-03
# iteration 18500	 train mse: 2.013E-03
# iteration 18600	 train mse: 1.729E-03
# iteration 18700	 train mse: 1.656E-03
# iteration 18800	 train mse: 1.850E-03
# iteration 18900	 train mse: 1.943E-03
# iteration 19000	 train mse: 1.996E-03
# iteration 19100	 train mse: 1.712E-03
# iteration 19200	 train mse: 1.641E-03
# iteration 19300	 train mse: 1.834E-03
# iteration 19400	 train mse: 1.926E-03
# iteration 19500	 train mse: 1.981E-03
# iteration 19600	 train mse: 1.699E-03
# iteration 19700	 train mse: 1.634E-03
# iteration 19800	 train mse: 1.819E-03
# iteration 19900	 train mse: 1.911E-03
# Model saved in file: /tmp/cnnx4_test3

# %%
tf.reset_default_graph()
model_dict=apply_classification_loss_mse(kernels1=[7,7,7],kernels2=[7,7,7],
                                     filters1=[64,64,64],filters2=[64,64,3],
                                     pool_size=[1,2,2,2,2,1],learning_rate=0.0001)
saver = train_model(model_dict, [], train_every=100, test_every=2000,load=False,
                    fname='cifar10_recon4',outname='/tmp/cnnx4_test4')
# Out:
# iteration 0	 train mse: 2.205E-01
# iteration 0	 TEST MSE: 2.515E-01	 TEST MSE(Quantized): 2.515E-01
# /home/mtezcan/anaconda3/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: ../cifar10_recon4/lena4_0.tiff is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/mtezcan/anaconda3/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: 
# iteration 7300	 train mse: 2.507E-03
# iteration 7400	 train mse: 2.437E-03
# iteration 7500	 train mse: 2.547E-03
# iteration 7600	 train mse: 2.140E-03
# iteration 7700	 train mse: 2.279E-03
# iteration 7800	 train mse: 2.338E-03
# iteration 7900	 train mse: 2.517E-03
# iteration 8000	 train mse: 2.393E-03
# iteration 8000	 TEST MSE: 2.235E-03	 TEST MSE(Quantized): 2.236E-03
# iteration 8100	 train mse: 2.068E-03
# iteration 8200	 train mse: 1.995E-03
# iteration 8300	 train mse: 2.294E-03
# iteration 8400	 train mse: 2.284E-03
# iteration 8500	 train mse: 2.441E-03
# iteration 8600	 train mse: 2.034E-03
# iteration 8700	 train mse: 1.945E-03
# iteration 8800	 train mse: 2.221E-03
# iteration 8900	 train mse: 2.548E-03
# iteration 9000	 train mse: 2.340E-03
# iteration 9100	 train mse: 2.005E-03
# iteration 9200	 train mse: 1.906E-03
# iteration 9300	 train mse: 2.207E-03
# iteration 9400	 train mse: 2.144E-03
# iteration 9500	 train mse: 2.255E-03
# iteration 9600	 train mse: 1.974E-03
# iteration 9700	 train mse: 1.887E-03
# iteration 9800	 train mse: 2.005E-03
# iteration 9900	 train mse: 2.834E-03
# iteration 10000	 train mse: 2.185E-03
# iteration 10000	 TEST MSE: 2.037E-03	 TEST MSE(Quantized): 2.038E-03
# iteration 10100	 train mse: 1.866E-03
# iteration 10200	 train mse: 1.755E-03
# iteration 10300	 train mse: 2.041E-03
# iteration 10400	 train mse: 2.062E-03
# iteration 10500	 train mse: 2.188E-03
# iteration 10600	 train mse: 1.808E-03
# iteration 10700	 train mse: 1.900E-03
# iteration 10800	 train mse: 1.897E-03
# iteration 10900	 train mse: 2.371E-03
# iteration 11000	 train mse: 2.056E-03
# iteration 11100	 train mse: 1.794E-03
# iteration 11200	 train mse: 1.762E-03
# iteration 11300	 train mse: 1.842E-03
# iteration 11400	 train mse: 1.917E-03
# iteration 11500	 train mse: 2.079E-03
# iteration 11600	 train mse: 1.813E-03
# iteration 11700	 train mse: 1.629E-03
# iteration 11800	 train mse: 1.882E-03
# iteration 11900	 train mse: 1.954E-03
# iteration 12000	 train mse: 1.975E-03
# iteration 12000	 TEST MSE: 1.837E-03	 TEST MSE(Quantized): 1.838E-03
# iteration 12100	 train mse: 1.706E-03
# iteration 12200	 train mse: 1.683E-03
# iteration 12300	 train mse: 1.834E-03
# iteration 12400	 train mse: 1.856E-03
# iteration 12500	 train mse: 2.030E-03
# iteration 12600	 train mse: 1.734E-03
# iteration 12700	 train mse: 1.592E-03
# iteration 12800	 train mse: 1.744E-03
# iteration 12900	 train mse: 1.794E-03
# iteration 13000	 train mse: 1.885E-03
# iteration 13100	 train mse: 1.640E-03
# iteration 13200	 train mse: 1.525E-03
# iteration 13300	 train mse: 1.884E-03
# iteration 13400	 train mse: 1.752E-03
# iteration 13500	 train mse: 1.814E-03
# iteration 13600	 train mse: 1.576E-03
# iteration 13700	 train mse: 1.703E-03
# iteration 13800	 train mse: 1.731E-03
# iteration 13900	 train mse: 1.741E-03
# iteration 14000	 train mse: 1.903E-03
# iteration 14000	 TEST MSE: 1.776E-03	 TEST MSE(Quantized): 1.776E-03
# iteration 14100	 train mse: 1.546E-03
# iteration 14200	 train mse: 1.485E-03
# iteration 14300	 train mse: 1.734E-03
# iteration 14400	 train mse: 1.687E-03
# iteration 14500	 train mse: 1.812E-03
# iteration 14600	 train mse: 1.539E-03
# iteration 14700	 train mse: 1.441E-03
# iteration 14800	 train mse: 1.740E-03
# iteration 14900	 train mse: 1.683E-03
# iteration 15000	 train mse: 1.797E-03
# iteration 15100	 train mse: 1.478E-03
# iteration 15200	 train mse: 1.442E-03
# iteration 15300	 train mse: 1.795E-03
# iteration 15400	 train mse: 1.871E-03
# iteration 15500	 train mse: 1.742E-03
# iteration 15600	 train mse: 1.447E-03
# iteration 15700	 train mse: 1.362E-03
# iteration 15800	 train mse: 1.656E-03
# iteration 15900	 train mse: 1.602E-03
# iteration 16000	 train mse: 1.715E-03
# iteration 16000	 TEST MSE: 1.593E-03	 TEST MSE(Quantized): 1.595E-03
# iteration 16100	 train mse: 1.450E-03
# iteration 16200	 train mse: 1.357E-03
# iteration 16300	 train mse: 1.478E-03
# iteration 16400	 train mse: 1.611E-03
# iteration 16500	 train mse: 1.679E-03
# iteration 16600	 train mse: 1.476E-03
# iteration 16700	 train mse: 1.309E-03
# iteration 16800	 train mse: 1.483E-03
# iteration 16900	 train mse: 1.539E-03
# iteration 17000	 train mse: 1.667E-03
# iteration 17100	 train mse: 1.521E-03
# iteration 17200	 train mse: 1.297E-03
# iteration 17300	 train mse: 1.485E-03
# iteration 17400	 train mse: 1.501E-03
# iteration 17500	 train mse: 1.624E-03
# iteration 17600	 train mse: 1.342E-03
# iteration 17700	 train mse: 1.263E-03
# iteration 17800	 train mse: 1.400E-03
# iteration 17900	 train mse: 1.490E-03
# iteration 18000	 train mse: 1.541E-03
# iteration 18000	 TEST MSE: 1.424E-03	 TEST MSE(Quantized): 1.425E-03
# iteration 18100	 train mse: 1.380E-03
# iteration 18200	 train mse: 1.269E-03
# iteration 18300	 train mse: 1.583E-03
# iteration 18400	 train mse: 1.455E-03
# iteration 18500	 train mse: 1.511E-03
# iteration 18600	 train mse: 1.386E-03
# iteration 18700	 train mse: 1.217E-03
# iteration 18800	 train mse: 1.415E-03
# iteration 18900	 train mse: 1.432E-03
# iteration 19000	 train mse: 1.704E-03
# iteration 19100	 train mse: 1.390E-03
# iteration 19200	 train mse: 1.244E-03
# iteration 19300	 train mse: 1.368E-03
# iteration 19400	 train mse: 1.409E-03
# iteration 19500	 train mse: 1.559E-03
# iteration 19600	 train mse: 1.254E-03
# iteration 19700	 train mse: 1.305E-03
# iteration 19800	 train mse: 1.347E-03
# iteration 19900	 train mse: 1.372E-03
# Model saved in file: /tmp/cnnx4_test4

# %%
tf.reset_default_graph()
model_dict=apply_classification_loss_mse(kernels1=[5,5,5,5,5],kernels2=[5,5,5,5,5],
                                     filters1=[16,32,64,64,128],filters2=[64,64,32,16,3],
                                     pool_size=[1,2,1,2,1,1,2,1,2,1],learning_rate=0.0001)
saver = train_model(model_dict, [], train_every=100, test_every=2000,load=False,
                    fname='cifar10_recon5',outname='/tmp/cnnx4_test5')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-5ba18a5bac85> in <module>()
# ----> 1 tf.reset_default_graph()
#       2 model_dict=apply_classification_loss_mse(kernels1=[5,5,5,5,5],kernels2=[5,5,5,5,5],
#       3                                      filters1=[16,32,64,64,128],filters2=[64,64,32,16,3],
#       4                                      pool_size=[1,2,1,2,1,1,2,1,2,1],learning_rate=0.0001)
#       5 saver = train_model(model_dict, [], train_every=100, test_every=2000,load=False,
#
# NameError: name 'tf' is not defined

# %%
tf.reset_default_graph()
model_dict=apply_classification_loss_mse(kernels1=[5,7,9],kernels2=[9,7,5],
                                     filters1=[16,64,128],filters2=[64,16,3],
                                     pool_size=[1,2,2,2,2,1],learning_rate=0.0001)
saver = train_model(model_dict, [], train_every=100, test_every=2000,load=False,
                    fname='cifar10_recon6',outname='/tmp/cnnx4_test6')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-32-7ecdd3519aa7> in <module>()
#       1 tf.reset_default_graph()
# ----> 2 model_dict=apply_classification_loss(kernels1=[5,7,9],kernels2=[9,7,5],
#       3                                      filters1=[16,64,128],filters2=[64,16,3],
#       4                                      pool_size=[1,1,2,2,1,1],learning_rate=0.0001)
#       5 saver = train_model(model_dict, [], train_every=100, test_every=500,fname='cifar10_recon2')
#
# NameError: name 'apply_classification_loss' is not defined

# %%
img = skimage.io.imread('../test_img_old/lion.tiff')
img_32=img2block(img)

tmp=x_tr.copy()
x_tr=img_32.copy()
idx=np.random.permutation(x_tr.shape[0])
x_tr=x_tr[idx,:,:,:]

tf.reset_default_graph()
model_dict=apply_classification_loss_mse(kernels1=[5,7,9],kernels2=[9,7,5],
                                     filters1=[16,64,128],filters2=[64,16,3],
                                     pool_size=[1,2,2,2,2,1],learning_rate=7e-5,FT=True)
tf.reset_default_graph()
model_dict=apply_classification_loss_mse(kernels1=[5,7,9],kernels2=[5,5],
                                     filters1=[16,64,128],filters2=[16,3],
                                     pool_size=[1,2,2,2,2],learning_rate=0.0001,FT=False)
saver = train_model(model_dict, [], train_every=100, test_every=1000,load=True,
                    fname='cifar10_recon0',outname='/tmp/cnn_autoencoderx16',ftname='/tmp/cnnx4_test0')

x_tr=tmp.copy()
# Out:
# INFO:tensorflow:Restoring parameters from /tmp/cnn_autoencoderx16
# Model loaded
# iteration 0	 train mse: 6.739E-04
# iteration 0	 TEST MSE: 3.041E-03	 TEST MSE(Quantized): 3.042E-03
# iteration 100	 train mse: 4.539E-04
# iteration 200	 train mse: 5.587E-04
# iteration 300	 train mse: 5.086E-04
# iteration 400	 train mse: 6.164E-04
# iteration 500	 train mse: 5.478E-04
# iteration 600	 train mse: 6.552E-04
# iteration 700	 train mse: 5.413E-04
# iteration 800	 train mse: 5.983E-04
# iteration 900	 train mse: 4.947E-04
# iteration 1000	 train mse: 5.851E-04
# iteration 1000	 TEST MSE: 2.817E-03	 TEST MSE(Quantized): 2.818E-03
# iteration 1100	 train mse: 5.438E-04
# iteration 1200	 train mse: 4.355E-04
# iteration 7300	 train mse: 5.076E-04
# iteration 7400	 train mse: 3.912E-04
# iteration 7500	 train mse: 4.008E-04
# iteration 7600	 train mse: 5.361E-04
# iteration 7700	 train mse: 4.648E-04
# iteration 7800	 train mse: 4.881E-04
# iteration 7900	 train mse: 3.269E-04
# iteration 8000	 train mse: 2.656E-04
# iteration 8000	 TEST MSE: 2.675E-03	 TEST MSE(Quantized): 2.676E-03
# iteration 8100	 train mse: 3.662E-04
# iteration 8200	 train mse: 4.107E-04
# iteration 8300	 train mse: 3.890E-04
# iteration 8400	 train mse: 4.336E-04
# iteration 8500	 train mse: 4.120E-04
# iteration 8600	 train mse: 4.366E-04
# iteration 8700	 train mse: 4.158E-04
# iteration 8800	 train mse: 4.469E-04
# iteration 8900	 train mse: 3.465E-04
# iteration 9000	 train mse: 4.593E-04
# iteration 9000	 TEST MSE: 2.874E-03	 TEST MSE(Quantized): 2.875E-03
# iteration 9100	 train mse: 5.490E-04
# iteration 9200	 train mse: 6.836E-04
# iteration 9300	 train mse: 3.567E-04
# iteration 9400	 train mse: 5.313E-04
# iteration 9500	 train mse: 5.299E-04
# iteration 9600	 train mse: 3.578E-04
# iteration 9700	 train mse: 5.552E-04
# iteration 9800	 train mse: 4.117E-04
# iteration 9900	 train mse: 3.756E-04
# Model saved in file: /tmp/cnn_autoencoder_lionx8

# %%
#model_dict=apply_classification_loss_mse(kernels1=[5,7,9],kernels2=[5,5],
#                                     filters1=[16,64,128],filters2=[16,3],
#                                     pool_size=[1,2,2,2,2],learning_rate=0.0001,FT=False)

tf.reset_default_graph()
model_dict=apply_classification_loss_mse(kernels1=[5,7,9],kernels2=[9,7,5],
                                     filters1=[16,64,128],filters2=[64,16,3],
                                     pool_size=[1,2,2,2,2,1],learning_rate=7e-5)
tfsave ='/tmp/cnnx4_test0'
imgpath = '../test_img_old/lion.tiff'
outpath='../test_img/lion_recon2_convplusx8.tiff'
with model_dict['graph'].as_default(), tf.Session() as sess:
#with tf.Session() as sess:
    sess.run(tf.global_variables_initializer())
    '''
    var_list=[]
    with tf.variable_scope('conv1',reuse=True):
        var_list.append ( tf.get_variable('kernel') )
    '''
    saver = tf.train.Saver()
    saver.restore(sess, tfsave)
    print("Model loaded")
    
    img = skimage.io.imread(imgpath)
    [w,l,c]=img.shape
    img_32=img2block(img)
    img_block = np.zeros(img_32.shape)
    
    n= np.floor(img_32.shape[0]/2000).astype(int)
    print(n)
    for i in range(0,n):
        print(str(i+1)+'th slice')
        img_block[i*2000:(i+1)*2000,:,:,:]=sess.run(model_dict['outputs'], 
                                    feed_dict={model_dict['inputs']:img_32[i*2000:(i+1)*2000,:,:,:]})
    img_block[n*2000:,:,:,:]=sess.run(model_dict['outputs'], 
                                    feed_dict={model_dict['inputs']:img_32[n*2000:,:,:,:]})
        
    img_recon=block2img(img_block,(w,l))
    img_recon = convert2uint8(img_recon*255.)
    skimage.io.imsave(outpath,img_recon)
# Out:
# INFO:tensorflow:Restoring parameters from /tmp/cnnx4_test0
# Model loaded
# 5
# 1th slice
# 2th slice
# 3th slice
# 4th slice
# 5th slice
